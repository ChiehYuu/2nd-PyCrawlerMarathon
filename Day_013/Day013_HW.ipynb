# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
'''
Your Code
'''
import requests 
from bs4 import BeautifulSoup as Soup
url = 'https://www.ptt.cc/bbs/NBA/index.html'
response = requests.get(url,cookies={'over18':'1'})
soup = Soup(response.text,'html5lib')
for i in soup.find_all(class_='title'):
    try:
        r = Soup(requests.get('https://www.ptt.cc'+i.find('a')['href']).text, "html5lib")
        print('作者：' + r.find(class_='article-meta-value').text)
        print('標題：' + i.text.replace('\t','').replace('\n',''))
        print('時間：' + r.find_all(class_='article-meta-value')[3].text)
        print()
    except:
        continue
# Out:
# 作者：somanyee (Soman)
# 標題：Re: [花邊] Nike不發布萊恩災難財 傳線上商店停售相
# 時間：Wed Mar 11 07:13:29 2020
#
# 作者：Rambo (香帥)
# 標題：[Live] 騎士 @ 公牛
# 時間：Wed Mar 11 07:30:04 2020
#
# 作者：Rambo (香帥)
# 標題：[Live] 灰狼 @ 火箭
# 時間：Wed Mar 11 07:30:04 2020
#
# 作者：Rambo (香帥)
# 標題：[Live] 獨行俠 @ 馬刺
# 時間：Wed Mar 11 07:30:04 2020
#
# 作者：yowhatsupsli (賣火柴的小女孩)
# 標題：[情報] 巴爵士回擊嘴綠「搶工作」說
# 時間：Wed Mar 11 07:48:41 2020
#
# 作者：LABOYS (There's a hero)
# 標題：Re: [討論] 艇湖最後五分鐘-LeBron挑人打
# 時間：Wed Mar 11 08:13:57 2020
#
# 作者：Wojnarowski (@wojespn)
# 標題：[外絮] LBJ改口：是否空場比賽要聽專家的
# 時間：Wed Mar 11 08:22:18 2020
#
# 作者：currykukuo (陳菊濕汗)
# 標題：Re: [外絮] LBJ改口：是否空場比賽要聽專家的
# 時間：Wed Mar 11 09:02:47 2020
#
# 作者：Rambo (香帥)
# 標題：[Live] 太陽 @ 拓荒者
# 時間：Wed Mar 11 09:30:04 2020
#
# 作者：wegaman (.........)
# 標題：Re: [討論] LBJ跟MJ都是GOAT不行嗎？
# 時間：Wed Mar 11 09:38:07 2020
#
# 作者：jack34031 (井底之蛙)
# 標題：[情報] 塞爾提克確定進季後賽
# 時間：Wed Mar 11 09:38:41 2020
#
# 作者：currykukuo (陳菊濕汗)
# 標題：[情報] 馬刺留人機會不高　美媒爆尼克有興趣爭取德羅贊
# 時間：Wed Mar 11 09:42:37 2020
#
# 作者：Rambo (香帥)
# ...

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
'''
Your Code
'''
items =  soup.find_all('a',{'class':'btn wide'})
for i in items:
    if i.text == '最舊':
        firstpage = i['href']
    else:
        continue
url_firstpage = 'https://www.ptt.cc'+firstpage
soup =Soup(requests.get(url_firstpage,cookies = {'over18':'1'}).text,'html5lib')
for i in soup.find_all(class_='title'):
    try:
        r = Soup(requests.get('https://www.ptt.cc'+i.find('a')['href']).text, "html5lib")
        print('作者：' + r.find(class_='article-meta-value').text)
        print('標題：' + i.text.replace('\t','').replace('\n',''))
        print('時間：' + r.find_all(class_='article-meta-value')[3].text)
        print()
    except:
        continue
# Out:
# 作者：Price (Price)
# 標題：[轉錄]Lyotard 對於太陽板討論串的結論
# 時間：Sun May 16 01:54:33 2004
#
# 作者：Price (Price)
# 標題：[公告] 請停止一切關於本次活動的發言
# 時間：Mon May 24 00:43:00 2004
#
# 作者：Frankaze (神采風華)
# 標題：[轉錄]跟之前那篇比起來 我覺得這篇也應該轉過來
# 時間：Tue Jun  8 01:16:45 2004
#
# 作者：Frankaze (神采風華)
# 標題：[轉錄]再轉一篇好文來
# 時間：Tue Jun  8 09:02:23 2004
#
# 作者：Price (Price)
# 標題：[轉錄][情報] 夏洛特山貓系列
# 時間：Thu Jun 10 00:39:35 2004
#
# 作者：Price (Price)
# 標題：[轉錄]Re: [心得] 真是受不了糗爺....
# 時間：Thu Jun 10 00:51:35 2004
#
# 作者：Price (Price)
# 標題：[轉錄]總冠軍賽NO.2觀後感
# 時間：Thu Jun 10 12:05:07 2004
#
# 作者：AmuroNamie (原來太嗨真的會失眠^___^)
# 標題：[心得] Rasheed Wallace
# 時間：Fri Jun 11 15:06:09 2004
#
# 作者：toptree (  )
# 標題：掌控球賽的男人
# 時間：Sat Jun 12 07:13:04 2004
#
# 作者：skchang (3EB板開板囉！)
# 標題：[閒聊] 說說2004季後賽名場面回顧
# 時間：Sat Jun 12 13:21:49 2004
#
# 作者：shineup ()
# 標題：[心得] 其實說穿了 就是活塞的防守太可怕了
# 時間：Sat Jun 12 13:12:47 2004
#
# 作者：cOvi (喵~)
# 標題：Re: [閒聊] 說說2004季後賽名場面回顧
# 時間：Sat Jun 12 16:43:07 2004
#
# 作者：ykshih (￼N￼Ns)
# 標題：Re: [閒聊] 說說2004季後賽名場面回顧
# ...

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
'''
Your Code
'''
import requests 
from bs4 import BeautifulSoup as Soup
url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
response = requests.get(url,cookies={'over18':'1'})
soup = Soup(response.text,'html5lib')
for i in soup.find_all(class_='title'):
    print(i.text.replace('\t','').replace('\n',''))
    try:
        r = Soup(requests.get('https://www.ptt.cc'+i.find('a')['href'],cookies={'over18':'1'}).text, "html5lib")
        print('作者： ' + r.find(class_='article-meta-value').text)
        print('時間：' + r.find_all(class_='article-meta-value')[3].text)
    except:
        continue
# Out:
# [爆卦] 民眾黨發言人最新回應
# 作者： smisfun (Lin_Ah_Ma_Le)
# 時間：Wed Mar 11 10:14:30 2020
# [問卦] 女同事大喊其他女同事的罩杯?
# 作者： CavendishJr (卡文迪許jr)
# 時間：Wed Mar 11 10:14:55 2020
# [問卦] F奶是不是比時鐘放小明回家重要
# 作者： opfish (coco)
# 時間：Wed Mar 11 10:15:07 2020
# [新聞] 張益贍、蔡宜芳驚爆不倫戀　民眾黨：張
# 作者： thouloveme (赫赫)
# 時間：Wed Mar 11 10:16:15 2020
# Re: [問卦] KKC為什麼把文章都刪除了?
# 作者： hamasakiayu (ayumi)
# 時間：Wed Mar 11 10:16:41 2020
# [問卦] 上摩鐵開會也會有開會紀錄嗎?
# 作者： jeff0025 ()
# 時間：Wed Mar 11 10:16:55 2020
# Re: [爆卦] 民眾黨發言人最新回應
# 作者： VVizZ (我很窮)
# 時間：Wed Mar 11 10:16:59 2020
# Re: [問卦] 大家同學最早死的在幾歲？
# 作者： utdsml (阿邊肥)
# 時間：Wed Mar 11 10:17:10 2020
# [問卦] 8+9幫處女開苞時在想什麼
# 作者： nikubou5566 (隼人)
# 時間：Wed Mar 11 10:18:38 2020
# [問卦] 煩惱！開會地點選擇
# 作者： darknesschun (俊特斌)
# 時間：Wed Mar 11 10:18:47 2020
# [新聞] 終於回來！華航包機台商返台 57人進林口
# 作者： oceanplus (plus++)
# 時間：Wed Mar 11 10:19:13 2020
# [爆卦] 全球武漢肺炎地圖 台灣被納入中國統計
# 作者： AllenHuang (∴'☆:∵★.＼:)
# 時間：Wed Mar 11 10:19:28 2020
# [新聞] 民眾黨蔡宜芳、張益贍被傳上摩鐵 柯文哲
# 作者： rhino0314 (鬼島夢想家)
# 時間：Wed Mar 11 10:19:35 2020
# ...

# %%
r = Soup(requests.get('https://www.ptt.cc'+i.find('a')['href'],cookies={'over18':'1'}).text, "html5lib" )
r
# Out:
# <!DOCTYPE html>
# <html><head>
# 		<meta charset="utf-8"/>
#
#
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
#
# <title>[協尋] 急~親人走失，麻煩台北、新北鄉民幫忙協 - 看板 Gossiping - 批踢踢實業坊</title>
# <meta content="all" name="robots"/>
# <meta content="Ptt BBS 批踢踢" name="keywords"/>
# <meta content="幫忙代Po：
# 親人走失，拜託各位神通廣大的八卦版鄉民幫忙協尋，若有任何線索麻煩提供給家屬，謝
# 謝大家！ ｭ(_ _)m
# 尋人啟事
# http://imgur.com/gallery/zWu2xzT
# " name="description"/>
# <meta content="Ptt 批踢踢實業坊" property="og:site_name"/>
# <meta content="[協尋] 急~親人走失，麻煩台北、新北鄉民幫忙協" property="og:title"/>
# <meta content="幫忙代Po：
# 親人走失，拜託各位神通廣大的八卦版鄉民幫忙協尋，若有任何線索麻煩提供給家屬，謝
# 謝大家！ ｭ(_ _)m
# 尋人啟事
# http://imgur.com/gallery/zWu2xzT
# " property="og:description"/>
# <link href="https://www.ptt.cc/bbs/Gossiping/M.1583814803.A.FDE.html" rel="canonical"/>
#
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# ...

# %%
r.find_all(class_='article-meta-value')[3].text
# Out:
# 'Tue Mar 10 12:33:20 2020'

# %%
soup
# Out:
# <!DOCTYPE html>
# <html><head>
# 		<meta charset="utf-8"/>
#
#
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div class="bbs-content" id="topbar">
# 		<a href="/bbs/" id="logo">批踢踢實業坊</a>
# 		<span>›</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# ...
