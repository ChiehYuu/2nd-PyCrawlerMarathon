# %% [markdown]
# # 反爬：登入授權模擬
#
# * 了解「登入權限機制」的反爬蟲機制
# * 「登入權限機制」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 找一個需要登入的網站試試看，並說明思考流程
# （如果不知道要用哪個網站的話，可以試試看 https://github.com/new 網址，未登入時會被導向登入頁）

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.books.com.tw/'
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'
}
cookies= {
    'Cookie': 'bid=5dbbd2985f76f; __lt__cid=2364a855-b2ac-4388-8be0-178c382bf81f; _fbp=fb.2.1572590232367.1154927229; _ga=GA1.3.1282379250.1572590232; __gads=ID=fb75d75d54b230dc:T=1572590237:S=ALNI_MasmCwYKAHezpb4RaLi2EYb0euTxQ; _fbc=fb.2.1580129966805.IwAR1yrcF2p1IM3sUvhl4kvCz_jwnB5zhDTklv_H0_Aikdy58IqIYnvFHS6vk; _gcl_au=1.1.1295178012.1581951208; _gcl_aw=GCL.1584806911.Cj0KCQjw9tbzBRDVARIsAMBplx_0x3gq4guJdnnugfsbUGG4ogmKnyaWa9itaYzBRQmdhqIBIeyCdF8aAhMMEALw_wcB; _gac_UA-4860506-1=1.1582695104.Cj0KCQiAqNPyBRCjARIsAKA-WFxzhCspnDN4mVNyJfW4oBew5cXbUi_A2lgi4-xMFOS3WPQOP_KXdF0aAodvEALw_wcB; CmsToken=fdd42fdPZtBzrm078TCoED%2BHl2u4%2FWrMNsv5clGMBpdz2bWpnwlWDvPz7f7GOWxtpsSUgJsEUPvM35pb%2B8KQwgJJ5O6JKci0fzlEbYPkAPOhj74X9j%2FJmErO8TKssNiUNbLdcHBIHLpn4aZ7zLNM2rT%2BsX84WLtVNzj6AFCNgdI1DLWpWm7pqGx2zLyqjJWVmfD7mG0r4EmcWPT8AS%2F4Ps8IZkYwvycA3ukLRx; __utma=196308671.1282379250.1572590232.1584807436.1584807436.1; __utmz=196308671.1584807436.1.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none); stepsession=XnZFuHB5YF4AAJ-VPioAAAAg; ssid=5dbbd2985f76f.1585957699; _gid=GA1.3.1943870654.1585957700; item_history=CN10123310+0010805895+0010819193+0010762863+0010799985+0010799983+0010764695+0010838944+0010704136+0010740436+0010716924+; home_tbanner=0; lpk=2d51af7c25f2630d8d0950f016d640bdadb998f41d6ecb86e543f5b0ae7e81f61448795a24d265c5; cid=jay50211; bday=1994%2F05%2F01; pd=B4MrZfvtxaT9wO9xvtv0yHgfrI; gud=691a8e420063ca3392753dd827c5f8a581a9f50b87fc3d66c9477a3d178bd6041472039f95a61e6d5ebabda88c887503344370231cb06ce98656e5048994e74a; bt=q88lns'
}
response = requests.get(url,verify = False ,headers=headers,cookies = cookies)
soup = BeautifulSoup(response.text,'html.parser')
soup
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.books.com.tw'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="zh-tw" http-equiv="Content-Language"/>
# <title>歡迎光臨博客來</title>
# <meta content="博客來,網路書店,線上購物,書籍,百貨,影音,設計,文具,美食,美妝" name="keywords"/>
# <meta content="博客來提供上百萬書籍、百貨、影音、設計、文具、美食、有機、美妝、服飾。網路書店有齊全的繁簡體外文書籍雜誌，購物網多樣性百貨設計商品滿足您購物需求。取貨安全方便，中午前訂7-11隔日取" name="description"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="博客來" property="og:site_name">
# <meta content="product" property="og:type">
# ...

# %%
#確認是否登入
ccc = soup.find_all('li',{'class':'logout li_label_member_login'})
ccc
# Out:
# [<li class="logout li_label_member_login" style="display:none;"><strong id="member_class"></strong> 您好 ( <a href="https://cart.books.com.tw/member/logout?loc=customer_004">登出</a> )</li>]
