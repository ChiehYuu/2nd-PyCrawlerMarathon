# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
import re


# 正則拆分網址
def RegexMatchingTest(regex, input_text):
    pattern = re.compile(regex)
    result = re.search(pattern, input_text)

    if result:
        if result.lastindex is not None:
            for i in range(0, result.lastindex+1):
                return result.group(2)
    else:
        return None
regex = "(\w+):\/\/([^/:]+)?([^# !>]*)"




browser = webdriver.Chrome(
    executable_path='..\chromedriver.exe')
# 目標文章數量
target_count = 500

article_count = 1
article_url = []
article_content = {}
keepGoing = True
url = "https://www.cupoy.com/newsfeed/topicgrp/life_tw"

browser.get(url)
time.sleep(5)

while keepGoing:
    html = browser.page_source
    soup = BeautifulSoup(html, "lxml")

    news_block = soup.find_all('div', class_='sc-eEieub sc-iuDHTM ibJqYc')

    for news_item in news_block:
        url = news_item.find(
            'a', class_='sc-RbTVP sc-kEmuub eSJXii').get("href")
        article_content.setdefault(article_count, {})
        # 目標文章數量-1篇之前處理
        if url not in article_url and article_count < target_count:
            article_url.append(url)
            article_content[article_count]['title'] = news_item.find('h6').string
            article_content[article_count]['category'] = news_item.find(
                'div', class_='sc-gacfCG bPSpUf').string
            article_content[article_count]['Summary'] = news_item.find(
                'p', class_='sc-FQuPU sc-ciodno bvnzOw').string
            article_content[article_count]['link'] = url               
            article_content[article_count]['domain'] = RegexMatchingTest(regex, url)   
            article_count += 1
        # 目標文章數量最後一篇處理
        elif url not in article_url and article_count == target_count:
            article_content[article_count]['title'] = news_item.find('h6').string
            article_content[article_count]['category'] = news_item.find(
                'div', class_='sc-gacfCG bPSpUf').string
            article_content[article_count]['Summary'] = news_item.find(
                'p', class_='sc-FQuPU sc-ciodno bvnzOw').string
            article_content[article_count]['link'] = url
            article_content[article_count]['domain'] = RegexMatchingTest(regex, url)
            keepGoing = False

    time.sleep(2)
    browser.execute_script("window.scrollBy(0,10000)")

# print(article_content)
browser.quit()
frame = pd.DataFrame(article_content)
frame.T
# Out:
#                                                  title category  \
# 1                5張表看觀光業紓困2.0！旅行社、旅館、導遊、遊樂園補助各領多少｜數位時代       旅遊
# 2                      高齡化社會來臨！醫療科技要怎麼做，才能解決長照問題？｜數位時代     醫療健康
# 3                  特斯拉全員降薪、放無薪假，電動車一哥被新冠肺炎疫情害得多慘？｜數位時代       汽車
# 4             特斯拉牌呼吸器亮相，與 Model 3 共用零件 | TechNews 科技新報       汽車
# 5        提高警覺！父母最容易「弄丟孩子」的五個瞬間，都是無法承受的痛 – 媽媽經｜專屬於媽媽的網站       育兒
# ..                                                 ...      ...
# 496                     生了孩子後，夫妻間的挑戰才開始 – 媽媽經｜專屬於媽媽的網站       育兒
# 497  圓圓家出去玩-一秒穿越千年，菡服體驗，古色古香古蹟蘆洲李宅內，變身千年前的美女體驗好新鮮 –...       育兒
# 498  圓圓家出去玩-鼻頭角步道，海上小長城，眺望270度海景超遼闊，步道好走很輕鬆 – 媽媽經｜專...       育兒
# 499  圓圓家出去玩-槺榔驛古輕便車，麋鹿造型好可愛，導覽人員全程專業導覽，還幫拍照!一人只要NT$...       旅遊
# 500       石頭也能煮成色香味俱全的「石頭湯」！教孩子打開心門與人分享 – 媽媽經｜專屬於媽媽的網站       育兒
#
#                                                Summary  \
# 1    交通部觀光局針對「疫情海嘯第一排」受影響的旅遊產業業者，提供了更細部的協助措施，對象擴大至導...
# 2    高齡化社會的帶來的長照問題，除了仰賴醫療技術的不斷進步，透過AR/VR、5G縮短問診距離、A...
# 3             在全美國工廠因疫情陷入停擺的情況下，特斯拉宣佈全員減薪，並且放無薪假直到5月初。
# 4    美國日趨嚴峻的武漢肺炎疫情讓電動車和火箭製造商馬斯克再次跨界當「斜槓中年」，這次他要在醫療器...
# 5    「小孩走失」、「小孩失蹤」這幾個字，對所有父母來說都是無法承受的字。牽著孩子的手握的更緊，無...
# ..                                                 ...
# 496  至親至疏是夫妻，說得一點都不錯。夫妻本是兩個陌生人，生長環境不一樣，男女有別，很多時候想法會...
# 497  收藏文章前陣子本來為了春酒表演，當時主題是穿越古今，為了這個主題google了好多資料 當時...
# 498  收藏文章一直很想前往的鼻頭角步道，總算在一個假日的午後成功挑戰 鼻頭角步道是目前圓圓媽挑戰的...
# 499  收藏文章每次到了我不是那麼熟悉的地方玩樂時，google大神就是我的在地導覽員 到了新竹，每...
# 500  三個和尚來到一個村子，由於歷經許多災難，使得村子裡的人們彼此不信任。最有智慧的和尚想出一個方...
#
#                                                   link            domain
# 1    https://www.bnext.com.tw/article/57254/gov-for...  www.bnext.com.tw
# 2    https://www.bnext.com.tw/article/57241/aging-s...  www.bnext.com.tw
# 3    https://www.bnext.com.tw/article/57248/tesla-p...  www.bnext.com.tw
# 4    https://technews.tw/2020/04/08/tesla-ventilato...       technews.tw
# 5    https://mamaclub.com/learn/%e6%8f%90%e9%ab%98%...      mamaclub.com
# ..                                                 ...               ...
# 496  https://mamaclub.com/learn/%e7%94%9f%e4%ba%86%...      mamaclub.com
# 497  https://mamaclub.com/learn/%e5%9c%93%e5%9c%93%...      mamaclub.com
# 498  https://mamaclub.com/learn/%e5%9c%93%e5%9c%93%...      mamaclub.com
# 499  https://mamaclub.com/learn/%e5%9c%93%e5%9c%93%...      mamaclub.com
# 500  https://mamaclub.com/learn/%e7%a1%ac%e9%82%a6%...      mamaclub.com
#
# [500 rows x 5 columns]
