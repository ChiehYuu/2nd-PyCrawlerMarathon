# %% [markdown]
# # 第一部分：爬蟲、資料整理

# %%
import re
import time
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import os 
import shutil
import hashlib
from tqdm import tqdm
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from multiprocessing import Pool

# %% [markdown]
# ## Top 500 文章爬蟲

# %%
data = {}
count = 1
browser = webdriver.Chrome('../chromedriver.exe')
url = 'https://www.cupoy.com/newsfeed/topstory'
browser.get(url)
time.sleep(10)
while True:
    
    # 基礎爬蟲
    html_source = browser.page_source
    soup = BeautifulSoup(html_source, "html5lib")
    res = soup.find_all('div', class_='sc-eEieub sc-iuDHTM ibJqYc')
    # 迴圈爬取資料並分類
    for item in res:
        data.setdefault(count,{})
        #分類或來源
        data[count]['category'] = item.find('div',{'class':'sc-gacfCG bPSpUf'}).text
        #文章來源網址
        data[count]['link'] = item.find('a').get('href')
        #標題
        data[count]['title'] = item.find('a').get('title')
        #簡介
        data[count]['summary'] = item.find('h6').string
        
        #文章標籤序列    
        count += 1
        
    #爬蟲進度顯示
    print(f"文章更新數... {count}")
    
    
    # 模擬器頁面下滑
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(1)

    # 計算新頁面高度
    browser.execute_script("return document.body.scrollHeight")
    
    # 設置文章數
    if count > 500:
        print("已超過500則文章")
        break
    time.sleep(5) 
    
browser.quit()
data
# Out:
# 文章更新數... 16
# 文章更新數... 33
# 文章更新數... 50
# 文章更新數... 67
# 文章更新數... 84
# 文章更新數... 101
# 文章更新數... 118
# 文章更新數... 135
# 文章更新數... 152
# 文章更新數... 169
# 文章更新數... 186
# 文章更新數... 203
# 文章更新數... 220
# 文章更新數... 237
# 文章更新數... 253
# 文章更新數... 270
# 文章更新數... 287
# 文章更新數... 304
# 文章更新數... 321
# 文章更新數... 338
# 文章更新數... 355
# 文章更新數... 372
# 文章更新數... 389
# 文章更新數... 406
# 文章更新數... 423
# 文章更新數... 440
# 文章更新數... 457
# 文章更新數... 474
# 文章更新數... 491
# 文章更新數... 508
# 已超過500則文章
# {1: {'category': '資訊安全',
#   'link': 'https://technews.tw/2020/04/23/academics-steal-data-from-air-gapped-systems-using-pc-fan-vibrations/?utm_source=fb_tn&utm_medium=facebook',
#   'title': '比利時研究團隊新發現：不上網，駭客利用電腦風扇也能竊取資料 | TechNews 科技新報',
#   'summary': '比利時研究團隊新發現：不上網，駭客利用電腦風扇也能竊取資料 | TechNews 科技新報'},
#  2: {'category': '科技',
#   'link': 'https://technews.tw/2020/04/23/over-hundred-professionalist-against-eid/?utm_source=fb_tn&utm_medium=facebook',
#   'title': '「數位身分證」即將上路，卻有百位學者專家連署反對 | TechNews 科技新報',
# ...

# %% [markdown]
# ## 資料整理

# %%
dataframe = pd.DataFrame(data)
df = dataframe.T
df.head()
# Out:
#   category                                               link  \
# 1     資訊安全  https://technews.tw/2020/04/23/academics-steal...
# 2       科技  https://technews.tw/2020/04/23/over-hundred-pr...
# 3     蘋果專區  https://technews.tw/2020/04/23/flaw-in-iphone-...
# 4       科技  https://technews.tw/2020/04/23/pompeo-says-wor...
# 5     職場白領                            http://sc.piee.pw/Q3A2U
#
#                                                title  \
# 1      比利時研究團隊新發現：不上網，駭客利用電腦風扇也能竊取資料 | TechNews 科技新報
# 2           「數位身分證」即將上路，卻有百位學者專家連署反對 | TechNews 科技新報
# 3  數億支 iPhone 及 iPad 驚爆「恐怖級」安全漏洞，駭客可獲取遠端存取完全權限 | ...
# 4          蓬佩奧：病毒起源需調查中國「多個」實驗室，不只武漢 | TechNews 科技新報
# 5                                  「吹哨」的英文怎麼說？ | 經理人
#
#                                              summary
# 1      比利時研究團隊新發現：不上網，駭客利用電腦風扇也能竊取資料 | TechNews 科技新報
# 2           「數位身分證」即將上路，卻有百位學者專家連署反對 | TechNews 科技新報
# 3  數億支 iPhone 及 iPad 驚爆「恐怖級」安全漏洞，駭客可獲取遠端存取完全權限 | ...
# 4          蓬佩奧：病毒起源需調查中國「多個」實驗室，不只武漢 | TechNews 科技新報
# ...

# %%
df.head(500).to_csv('news.csv')

# %%
df = pd.read_csv('news.csv')
df.head()
# Out:
#    Unnamed: 0 category                                               link  \
# 0           1     資訊安全  https://technews.tw/2020/04/23/academics-steal...
# 1           2       科技  https://technews.tw/2020/04/23/over-hundred-pr...
# 2           3     蘋果專區  https://technews.tw/2020/04/23/flaw-in-iphone-...
# 3           4       科技  https://technews.tw/2020/04/23/pompeo-says-wor...
# 4           5     職場白領                            http://sc.piee.pw/Q3A2U
#
#                                                title  \
# 0      比利時研究團隊新發現：不上網，駭客利用電腦風扇也能竊取資料 | TechNews 科技新報
# 1           「數位身分證」即將上路，卻有百位學者專家連署反對 | TechNews 科技新報
# 2  數億支 iPhone 及 iPad 驚爆「恐怖級」安全漏洞，駭客可獲取遠端存取完全權限 | ...
# 3          蓬佩奧：病毒起源需調查中國「多個」實驗室，不只武漢 | TechNews 科技新報
# 4                                  「吹哨」的英文怎麼說？ | 經理人
#
#                                              summary
# 0      比利時研究團隊新發現：不上網，駭客利用電腦風扇也能竊取資料 | TechNews 科技新報
# 1           「數位身分證」即將上路，卻有百位學者專家連署反對 | TechNews 科技新報
# ...

# %% [markdown]
# ## 爬取內文

# %%
path = './temp'
if os.path.exists(path):
        shutil.rmtree(path)
try:
    os.mkdir(path)
except OSError:
    print ("資料夾建立於 %s 失敗" % path)
else:
    print ("成功建立資料夾於 %s " % path)
# Out:
# 成功建立資料夾於 ./temp

# %%
for index, row in tqdm(df.iterrows(), total=len(df)):
    # check url correct
    res = requests.get(row['link']) 
    # extract text from website
    text_raw = str()
    soup = BeautifulSoup(res.text, "html.parser")
    for i in soup.find_all('p'):
        text_raw += i.text  
    text_raw = text_raw.replace('\n','')
    text = text_raw.replace('\r','')    
    # save as .txt
    ## use hash as file name to avoid filename error
    with open(os.path.join(path, str(index) + ".txt"), 'w', encoding='utf-8') as f:
        f.write(text)
    
    #break
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 500/500 [05:51<00:00,  1.42it/s]

# %% [markdown]
# # 第二部分：視覺化分析

# %%
plt.rcParams['font.sans-serif'] = ['SimSun']  
plt.rcParams['axes.unicode_minus'] = False   
plt.rcParams['font.size'] = 14

plt.figure(figsize=(20,10))
plt.xlabel('新聞分類')
plt.ylabel('新聞筆數')
plt.title('擷取新聞分類數')
plt.hist(df['category'],bins=18,edgecolor='#EFB28C',color='#EED19C',linewidth=1)
plt.show()

# 計算次數後轉換Dataframe
df_temp =df.category.value_counts().rename_axis('category').reset_index(name='counts')

plt.figure(figsize=(20,20))    

labels = df_temp["category"]      
size = df_temp["counts"]                     
plt.pie(size , labels = labels,autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %%
import jieba
import jieba.analyse

jieba.analyse.set_stop_words("./jieba_TW_stopWord.txt")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-40-3bdcf8f8bd8b> in <module>
#       2 import jieba.analyse
#       3
# ----> 4 jieba.analyse.set_stop_words("./jieba_TW_stopWord.txt")
#
# C:\ProgramData\Anaconda3\lib\site-packages\jieba\analyse\__init__.py in set_stop_words(stop_words_path)
#      15
#      16 def set_stop_words(stop_words_path):
# ---> 17     default_tfidf.set_stop_words(stop_words_path)
#      18     default_textrank.set_stop_words(stop_words_path)
#
# C:\ProgramData\Anaconda3\lib\site-packages\jieba\analyse\tfidf.py in set_stop_words(self, stop_words_path)
#      25         if not os.path.isfile(abs_path):
#      26             raise Exception("jieba: file does not exist: " + abs_path)
# ---> 27         content = open(abs_path, 'rb').read().decode('utf-8')
#      28         for line in content.splitlines():
# ...

# %%
keyword_list = []
for txt_name in tqdm(os.listdir(path)):
    txt_path = os.path.join(path, txt_name)
    with open(txt_path, 'r', encoding='utf-8') as f:
        text = str()
        for line in f:
            text += line.strip() + ' '
        
        # check if .txt empty
        if len(text) == 0: continue 
            
        # extract only top-50 keywords from each website
        keyword_list += jieba.analyse.extract_tags(text, 
                                                   topK=50, 
                                                   withWeight=False, 
                                                   allowPOS=())
# Out:
#   0%|                                                                                          | 0/500 [00:00<?, ?it/s]Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\ASROCK\AppData\Local\Temp\jieba.cache
# Loading model cost 0.622 seconds.
# Prefix dict has been built successfully.
# 100%|████████████████████████████████████████████████████████████████████████████████| 500/500 [00:06<00:00, 81.17it/s]

# %%
def count_segment_freq(keyword_list):
    keyword_df = pd.DataFrame(keyword_list, columns=['keyword'])
    keyword_df['count'] = 1
    keyword_freq = keyword_df.groupby('keyword')['count'].sum().sort_values(ascending=False)
    keyword_freq = pd.DataFrame(keyword_freq)
    return keyword_freq

keyword_freq = count_segment_freq(keyword_list)
keyword_freq.head(20)
# Out:
#          count
# keyword
# 我們         136
# 2020       131
# 疫情          94
# 一個          90
# 台灣          83
# 因為          81
# 他們          70
# 問題          68
# 04          67
# 23          66
# 00          65
# 20          64
# 進行          63
# 時間          60
# 10          56
# 15          55
# 市場          52
# 防疫          50
# 這些          49
# 中國          48

# %%
sns.set(style="whitegrid")
sns.barplot(x=keyword_freq.index, y=keyword_freq['count'], data=keyword_freq,
            label="Total", color="b")

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline

text = ' '.join(keyword_list) 
wc = WordCloud(collocations=False, 
               font_path='C:\Windows\Fonts\msjhbd.ttc', 
               width=1400, 
               height=1400, 
               margin=2).generate(text)
wc.to_file('./wordcloud.png')
plt.imshow(wc)
plt.axis("off")
plt.show()
